# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import warnings
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,}'.format

# %%
file_path = '/content/Alices Chocolate Ltd dataset (1).csv'
df = pd.read_csv(file_path)

# %%
df.head(3)
# Out:
#   Subsidiary/Country  Year  Month            Chocolate category  \
# 0              Italy  2023      7  Under 100 Calories chocolate
# 1              Italy  2022      4      White and ruby chocolate
# 2              Japan  2023     11       Dark and milk chocolate
#
#   Sales value (£)  Sales volume(Kg)  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         £58,862              1143         NaN         NaN         NaN
# 1         £52,107              1579         NaN         NaN         NaN
# 2         £73,215              1627         NaN         NaN         NaN
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN

# %%
df.shape
# Out:
# (648, 10)

# %%
df.isna().sum()
# Out:
# Subsidiary/Country      0
# Year                    0
# Month                   0
# Chocolate category      0
# Sales value (£)         0
# Sales volume(Kg)        0
# Unnamed: 6            648
# Unnamed: 7            648
# Unnamed: 8            648
# Unnamed: 9            648
# dtype: int64

# %%
del df['Unnamed: 6']
del df['Unnamed: 7']
del df['Unnamed: 8']
del df['Unnamed: 9']

# %%
df.head(3)
# Out:
#   Subsidiary/Country  Year  Month            Chocolate category  \
# 0              Italy  2023      7  Under 100 Calories chocolate
# 1              Italy  2022      4      White and ruby chocolate
# 2              Japan  2023     11       Dark and milk chocolate
#
#   Sales value (£)  Sales volume(Kg)
# 0         £58,862              1143
# 1         £52,107              1579
# 2         £73,215              1627

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subsidiary/Country  648 non-null    object
#  1   Year                648 non-null    int64
#  2   Month               648 non-null    int64
#  3   Chocolate category  648 non-null    object
#  4   Sales value (£)     648 non-null    object
#  5   Sales volume(Kg)    648 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 30.5+ KB

# %%
df.shape
# Out:
# (648, 6)

# %%
df.describe()
# Out:
#                      Year             Month  Sales volume(Kg)
# count               648.0             648.0             648.0
# mean  2,022.1851851851852               6.5  928.354938271605
# std    2.1711106488211787 3.454719237178034 607.3417773922631
# min               2,021.0               1.0          -1,094.0
# 25%               2,021.0              3.75             490.0
# 50%               2,022.0               6.5             816.0
# 75%               2,023.0              9.25           1,280.0
# max               2,043.0              12.0           3,857.0

# %%
# 1. Visualizing missing values as a matrix
msno.matrix(df)
plt.title("Missing Data Matrix")
plt.show()

# %%
# 3. Visualizing missing values as a heatmap
msno.heatmap(df, cmap="coolwarm", figsize=(8, 6))
plt.title("Missing Data Heatmap")
plt.show()

# %%
df.duplicated().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subsidiary/Country  648 non-null    object
#  1   Year                648 non-null    int64
#  2   Month               648 non-null    int64
#  3   Chocolate category  648 non-null    object
#  4   Sales value (£)     648 non-null    object
#  5   Sales volume(Kg)    648 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 30.5+ KB

# %%
df["Date"] = pd.to_datetime(df[["Year", "Month"]].assign(Day=1))  # Assuming Day=1
print(df)
# Out:
#     Subsidiary/Country  Year  Month            Chocolate category  \
# 0                Italy  2023      7  Under 100 Calories chocolate
# 1                Italy  2022      4      White and ruby chocolate
# 2                Japan  2023     11       Dark and milk chocolate
# 3                Italy  2021     10          Vegetarian Chocolate
# 4                   UK  2021     12       Dark and milk chocolate
# ..                 ...   ...    ...                           ...
# 643              Japan  2021     12       Reduced Sugar Chocolate
# 644              Italy  2023      7       Reduced Sugar Chocolate
# 645                 UK  2021      9  Under 100 Calories chocolate
# 646              Japan  2023      5      White and ruby chocolate
# 647              Japan  2022      3       Dark and milk chocolate
#
#     Sales value (£)  Sales volume(Kg)       Date
# 0           £58,862              1143 2023-07-01
# 1           £52,107              1579 2022-04-01
# ...

# %%
df.head(3)
# Out:
#   Subsidiary/Country  Year  Month            Chocolate category  \
# 0              Italy  2023      7  Under 100 Calories chocolate
# 1              Italy  2022      4      White and ruby chocolate
# 2              Japan  2023     11       Dark and milk chocolate
#
#   Sales value (£)  Sales volume(Kg)       Date
# 0         £58,862              1143 2023-07-01
# 1         £52,107              1579 2022-04-01
# 2         £73,215              1627 2023-11-01

# %%
# Extract Year and Month
df["YearMonth"] = df["Date"].dt.to_period("M")

# %%
df.head()
# Out:
#   Subsidiary/Country  Year  Month            Chocolate category  \
# 0              Italy  2023      7  Under 100 Calories chocolate
# 1              Italy  2022      4      White and ruby chocolate
# 2              Japan  2023     11       Dark and milk chocolate
# 3              Italy  2021     10          Vegetarian Chocolate
# 4                 UK  2021     12       Dark and milk chocolate
#
#   Sales value (£)  Sales volume(Kg)       Date YearMonth
# 0         £58,862              1143 2023-07-01   2023-07
# 1         £52,107              1579 2022-04-01   2022-04
# 2         £73,215              1627 2023-11-01   2023-11
# 3         £19,756               449 2021-10-01   2021-10
# 4         £51,663              1013 2021-12-01   2021-12

# %%
#del df['Date']

# %%
df.head()
# Out:
#   Subsidiary/Country  Year  Month            Chocolate category  \
# 0              Italy  2023      7  Under 100 Calories chocolate
# 1              Italy  2022      4      White and ruby chocolate
# 2              Japan  2023     11       Dark and milk chocolate
# 3              Italy  2021     10          Vegetarian Chocolate
# 4                 UK  2021     12       Dark and milk chocolate
#
#   Sales value (£)  Sales volume(Kg)       Date YearMonth
# 0         £58,862              1143 2023-07-01   2023-07
# 1         £52,107              1579 2022-04-01   2022-04
# 2         £73,215              1627 2023-11-01   2023-11
# 3         £19,756               449 2021-10-01   2021-10
# 4         £51,663              1013 2021-12-01   2021-12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subsidiary/Country  648 non-null    object
#  1   Year                648 non-null    int64
#  2   Month               648 non-null    int64
#  3   Chocolate category  648 non-null    object
#  4   Sales value (£)     648 non-null    object
#  5   Sales volume(Kg)    648 non-null    int64
#  6   Date                648 non-null    datetime64[ns]
#  7   YearMonth           648 non-null    period[M]
# dtypes: datetime64[ns](1), int64(3), object(3), period[M](1)
# memory usage: 40.6+ KB

# %%
df.rename(columns={'Sales value (£)':'Revenue', 'Sales volume(Kg)':'Sales_volume', 'Subsidiary/Country': 'Country'}, inplace=True)

# %%
df.head()
# Out:
#   Country  Year  Month            Chocolate category  Revenue  Sales_volume  \
# 0   Italy  2023      7  Under 100 Calories chocolate  £58,862          1143
# 1   Italy  2022      4      White and ruby chocolate  £52,107          1579
# 2   Japan  2023     11       Dark and milk chocolate  £73,215          1627
# 3   Italy  2021     10          Vegetarian Chocolate  £19,756           449
# 4      UK  2021     12       Dark and milk chocolate  £51,663          1013
#
#         Date YearMonth
# 0 2023-07-01   2023-07
# 1 2022-04-01   2022-04
# 2 2023-11-01   2023-11
# 3 2021-10-01   2021-10
# 4 2021-12-01   2021-12

# %%
grouped = df.groupby(["Year"]).agg(
    Total_Revenue=("Revenue", "sum"),
    Total_Volume=("Sales_volume", "sum")
).reset_index()

# %%
df['Year'].unique()
# Out:
# array([2023, 2022, 2021, 2043])

# %%
df[df['Year'] ==2043].describe()
# Out:
#          Year  Month      Sales_volume                 Date
# count     6.0    6.0               6.0                    6
# mean  2,043.0   12.0             569.0  2043-12-01 00:00:00
# min   2,043.0   12.0             115.0  2043-12-01 00:00:00
# 25%   2,043.0   12.0             453.5  2043-12-01 00:00:00
# 50%   2,043.0   12.0             585.5  2043-12-01 00:00:00
# 75%   2,043.0   12.0             677.0  2043-12-01 00:00:00
# max   2,043.0   12.0           1,011.0  2043-12-01 00:00:00
# std       0.0    0.0 298.2944853663909                  NaN

# %%
# Drop rows where Year is 2043
data = df[df["Year"] != 2043]

# %%
df['Date'] = df['Date'].dt.date

# %%
data['Year'].unique()
# Out:
# array([2023, 2022, 2021])

# %%
grouped = data.groupby(["Year"]).agg(
    Total_Revenue=("Revenue", "sum"),
    Total_Volume=("Sales_volume", "sum")
).reset_index()

# %%
grouped
# Out:
#    Year                                      Total_Revenue  Total_Volume
# 0  2021  £19,756£51,663£21,924£58,934£21,216£10,332£23,...        185805
# 1  2022  £52,107£108,031£91,650£29,898£17,259£30,331£12...        193919
# 2  2023  £58,862£73,215£20,288£119,685£26,070£12,513£58...        218436

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 642 entries, 0 to 647
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             642 non-null    object
#  1   Year                642 non-null    int64
#  2   Month               642 non-null    int64
#  3   Chocolate category  642 non-null    object
#  4   Revenue             642 non-null    object
#  5   Sales_volume        642 non-null    int64
#  6   Date                642 non-null    datetime64[ns]
#  7   YearMonth           642 non-null    period[M]
# dtypes: datetime64[ns](1), int64(3), object(3), period[M](1)
# memory usage: 45.1+ KB

# %%
# Remove the currency symbol and commas, then convert to float
data["Revenue"] = data["Revenue"].replace('[£,]', '', regex=True).astype(float)

# %%
# Step 1: Remove leading/trailing spaces


# Step 2: Remove non-numeric characters (e.g., commas, currency symbols)
df["Sales_volume"] = df["Sales_volume"].replace('[^0-9.]', '', regex=True)

# Step 3: Convert to float
df["Sales_volume"] = df["Sales_volume"].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 642 entries, 0 to 647
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             642 non-null    object
#  1   Year                642 non-null    int64
#  2   Month               642 non-null    int64
#  3   Chocolate category  642 non-null    object
#  4   Revenue             642 non-null    float64
#  5   Sales_volume        642 non-null    int64
#  6   Date                642 non-null    datetime64[ns]
#  7   YearMonth           642 non-null    period[M]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2), period[M](1)
# memory usage: 45.1+ KB

# %%
data['Year'] = data['Year'].astype(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 642 entries, 0 to 647
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             642 non-null    object
#  1   Year                642 non-null    object
#  2   Month               642 non-null    int64
#  3   Chocolate category  642 non-null    object
#  4   Revenue             642 non-null    float64
#  5   Sales_volume        642 non-null    int64
#  6   Date                642 non-null    datetime64[ns]
#  7   YearMonth           642 non-null    period[M]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3), period[M](1)
# memory usage: 45.1+ KB

# %%
grouped = data.groupby(["YearMonth"]).agg(
    Total_Revenue=("Revenue", "sum"),
    Total_Volume=("Sales_volume", "sum")
).reset_index()
# Save to Excel
grouped.to_excel("grouped_data.xlsx", index=False)

print("Grouped data saved to 'grouped_data.xlsx'")
# Out:
# Grouped data saved to 'grouped_data.xlsx'

# %%
grouped["YearMonth_str"] = grouped["YearMonth"].astype(str)

# %%
# Plot Total Revenue
plt.figure(figsize=(10, 8))
plt.plot(grouped["YearMonth_str"], grouped["Total_Revenue"], marker='o', color='blue', label='Total Revenue')
plt.title("Total Revenue Over Years")
plt.xlabel("Period")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Plot Total Volume
plt.figure(figsize=(10, 8))
plt.plot(grouped["YearMonth_str"], grouped["Total_Volume"], marker='o', color='green', label='Total Volume')
plt.title("Total Volume Over Years")
plt.xlabel("Period")
plt.ylabel("Total Volume")
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
data.head(3)
# Out:
#   Country  Year  Month            Chocolate category  Revenue  Sales_volume  \
# 0   Italy  2023      7  Under 100 Calories chocolate 58,862.0          1143
# 1   Italy  2022      4      White and ruby chocolate 52,107.0          1579
# 2   Japan  2023     11       Dark and milk chocolate 73,215.0          1627
#
#         Date YearMonth
# 0 2023-07-01   2023-07
# 1 2022-04-01   2022-04
# 2 2023-11-01   2023-11

# %%
data['Quarter'] = data['Date'].dt.quarter
data['Month_name'] = data['Date'].dt.month_name()

# %%
data.head(3)
# Out:
#   Country  Year  Month            Chocolate category  Revenue  Sales_volume  \
# 0   Italy  2023      7  Under 100 Calories chocolate 58,862.0          1143
# 1   Italy  2022      4      White and ruby chocolate 52,107.0          1579
# 2   Japan  2023     11       Dark and milk chocolate 73,215.0          1627
#
#         Date YearMonth  Quarter Month_name
# 0 2023-07-01   2023-07        3       July
# 1 2022-04-01   2022-04        2      April
# 2 2023-11-01   2023-11        4   November

# %%
data['Country'].unique()
# Out:
# array(['Italy', 'Japan', 'UK', 'United Kingdom'], dtype=object)

# %%
country_map = {'Italy':'Italy', 'Japan':'Japan', 'UK':'United Kingdom'}

# %%
data['Country'] = data['Country'].map(country_map)

# %%
data['Country'].unique()
# Out:
# array(['Italy', 'Japan', 'United Kingdom', nan], dtype=object)

# %%
data['Chocolate category'].unique()
# Out:
# array(['Under 100 Calories chocolate', 'White and ruby chocolate',
#        'Dark and milk chocolate', 'Vegetarian Chocolate',
#        'Organic chocolate', 'Reduced Sugar Chocolate',
#        'Vegetarian Chocolat$$$$££££', 'Organic ch0c0l@t£'], dtype=object)

# %%
data.rename(columns={'Chocolate category':'Chocolate_category'}, inplace=True)

# %%
data.head(2)
# Out:
#   Country  Year  Month            Chocolate_category  Revenue  Sales_volume  \
# 0   Italy  2023      7  Under 100 Calories chocolate 58,862.0          1143
# 1   Italy  2022      4      White and ruby chocolate 52,107.0          1579
#
#         Date YearMonth  Quarter Month_name
# 0 2023-07-01   2023-07        3       July
# 1 2022-04-01   2022-04        2      April

# %%
data.sample(3)
# Out:
#             Country  Year  Month        Chocolate_category  Revenue  \
# 281           Italy  2021      6  White and ruby chocolate 20,880.0
# 614           Japan  2023      6      Vegetarian Chocolate 15,745.0
# 301  United Kingdom  2023      7   Reduced Sugar Chocolate 24,717.0
#
#      Sales_volume       Date YearMonth  Quarter Month_name
# 281           720 2021-06-01   2021-06        2       June
# 614           335 2023-06-01   2023-06        2       June
# 301           749 2023-07-01   2023-07        3       July

# %%
chocolate_map = {'Under 100 Calories chocolate':'Under 100 Calories chocolate', 'White and ruby chocolate':'White and ruby chocolate', 'Dark and milk chocolate': 'Dark and milk chocolate', 'Vegetarian Chocolate': 'Vegetarian Chocolate', 'Organic chocolate':'Organic chocolate', 'Reduced Sugar Chocolate':'Reduced Sugar Chocolate', 'Vegetarian Chocolat$$$$££££': 'Vegetarian Chocolate', 'Organic ch0c0l@t£': 'Organic chocolate' }

# %%
data['Chocolate_category'] = data['Chocolate_category'].map(chocolate_map)

# %%
data.head()
# Out:
#           Country  Year  Month            Chocolate_category  Revenue  \
# 0           Italy  2023      7  Under 100 Calories chocolate 58,862.0
# 1           Italy  2022      4      White and ruby chocolate 52,107.0
# 2           Japan  2023     11       Dark and milk chocolate 73,215.0
# 3           Italy  2021     10          Vegetarian Chocolate 19,756.0
# 4  United Kingdom  2021     12       Dark and milk chocolate 51,663.0
#
#    Sales_volume       Date YearMonth  Quarter Month_name
# 0          1143 2023-07-01   2023-07        3       July
# 1          1579 2022-04-01   2022-04        2      April
# 2          1627 2023-11-01   2023-11        4   November
# 3           449 2021-10-01   2021-10        4    October
# 4          1013 2021-12-01   2021-12        4   December

# %%
data.rename(columns={'Chocolate category':'Chocolate_category'}, inplace=True)

# %%
data['Chocolate_category'].nunique()
# Out:
# 6

# %%
grouped = data.groupby(["Chocolate_category", "Country", 'Quarter']).agg(
    Total_Revenue=("Revenue", "sum"),
    #Total_Volume=("Sales_volume", "sum")
).sort_values(by='Total_Revenue', ascending=False).reset_index()

# %%
grouped
# Out:
#               Chocolate_category         Country  Quarter  Total_Revenue
# 0              Organic chocolate           Italy        4    1,279,123.0
# 1              Organic chocolate           Italy        3    1,256,083.0
# 2        Dark and milk chocolate           Italy        3    1,242,485.0
# 3        Dark and milk chocolate           Italy        4    1,125,494.0
# 4        Dark and milk chocolate           Italy        2    1,111,524.0
# ..                           ...             ...      ...            ...
# 67  Under 100 Calories chocolate  United Kingdom        3      106,585.0
# 68          Vegetarian Chocolate  United Kingdom        3      106,154.0
# 69  Under 100 Calories chocolate  United Kingdom        4      103,106.0
# 70      White and ruby chocolate  United Kingdom        4       95,871.0
# 71  Under 100 Calories chocolate  United Kingdom        1       90,147.0
#
# [72 rows x 4 columns]

# %%
# @title Total Revenue by Chocolate Category and Country

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(x='Chocolate_category', y='Total_Revenue', hue='Country', data=grouped)
plt.title('Total Revenue by Chocolate Category and Country')
plt.xlabel('Chocolate Category')
plt.ylabel('Total Revenue (£)')
plt.xticks(rotation=45, ha='right')
_ = plt.legend(title='Country')

# %%
# @title Chocolate_category vs Country

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Country'].value_counts()
    for x_label, grp in grouped.groupby('Chocolate_category')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Chocolate_category')
_ = plt.ylabel('Country')

# %%
# @title Total Volume by Chocolate Category

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(grouped['Chocolate_category'], grouped['Total_Volume'])
plt.title('Total Volume by Chocolate Category')
plt.xlabel('Chocolate Category')
plt.ylabel('Total Volume')
_ = plt.xticks(rotation=45, ha='right')

# %%
# @title Chocolate_category vs Total_Volume

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(grouped['Chocolate_category'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(grouped, x='Total_Volume', y='Chocolate_category', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# @title Total Revenue by Country

import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'grouped'
plt.figure(figsize=(8, 6))
plt.pie(grouped['Total_Revenue'], labels=grouped['Country'], autopct='%1.1f%%', startangle=90)
plt.title('Total Revenue by Country')
# Ensure the circle's proportion
_ = plt.axis('equal')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-e7e5dd24f2ca> in <cell line: 7>()
#       5 # Assuming your DataFrame is named 'grouped'
# ...

# %%
# @title Total Revenue by Chocolate Category

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.bar(grouped['Chocolate_category'], grouped['Total_Revenue'], color='skyblue')
plt.title('Total Revenue by Chocolate Category', fontsize=14)
plt.xlabel('Chocolate Category', fontsize=12)
plt.ylabel('Total Revenue (£)', fontsize=12)
plt.xticks(rotation=45, ha='right')
_ = plt.tight_layout()

# %%
#from tabulate import tabulate

# Display grouped data as a table
#print(tabulate(grouped, headers="keys", tablefmt="pretty"))

# %%
# Save grouped data to an Excel file
grouped.to_excel("Monthly_Revenue_and_Volume.xlsx", index=False)

print("Grouped data saved as 'Monthly_Revenue_and_Volume.xlsx'.")
# Out:
# Grouped data saved as 'Monthly_Revenue_and_Volume.xlsx'.

# %%
data.describe()
# Out:
#                    Month             Revenue      Sales_volume  \
# count              642.0               642.0             642.0
# mean  6.4485981308411215 46,609.814641744546 931.7133956386293
# min                  1.0           -14,592.0          -1,094.0
# 25%                  3.0            18,724.5             491.0
# 50%                  6.0            31,728.0             818.5
# 75%                  9.0            67,988.5          1,295.75
# max                 12.0           212,850.0           3,857.0
# std   3.4294320625938313 38,757.749722422384 608.6071093222828
#
#                                 Date            Quarter
# count                            642              642.0
# mean   2022-06-11 12:33:38.691588864  2.485981308411215
# min              2021-01-01 00:00:00                1.0
# 25%              2021-09-01 00:00:00                1.0
# 50%              2022-06-01 00:00:00                2.0
# 75%              2023-03-01 00:00:00                3.0
# ...

# %%
Choco_aver = data.groupby(['Chocolate_category', 'Year'])['Revenue'].agg('mean')
Choco_aver.to_excel('Choco Average.xlsx', index=True)

# %%
# Group by 'Chocolate_category' and calculate both mean and standard deviation
choco_stats = data.groupby('Chocolate_category')['Revenue'].agg(['mean', 'std'])
choco_stats = choco_stats.round(2)

# %%
choco_stats
# Out:
#                                   mean       std
# Chocolate_category
# Dark and milk chocolate      86,101.84 32,936.66
# Organic chocolate            92,318.44 38,265.19
# Reduced Sugar Chocolate      38,350.38 17,995.21
# Under 100 Calories chocolate 18,975.61 11,506.72
# Vegetarian Chocolate         18,149.87 11,136.71
# White and ruby chocolate     25,762.75  13,235.6

# %%
choco_stats.to_excel('Choco_expla.xlsx', index=True)

# %%
data.head(2)
# Out:
#   Country  Year  Month            Chocolate_category  Revenue  Sales_volume  \
# 0   Italy  2023      7  Under 100 Calories chocolate 58,862.0          1143
# 1   Italy  2022      4      White and ruby chocolate 52,107.0          1579
#
#         Date YearMonth  Quarter Month_name
# 0 2023-07-01   2023-07        3       July
# 1 2022-04-01   2022-04        2      April

# %%
data['YearMonth'] = data['YearMonth'].astype(str)

# %%
# Ensure 'YearMonth' is in the correct datetime format for sorting
data['YearMonth'] = pd.to_datetime(data['YearMonth'])

# Group data by YearMonth to calculate the total revenue for each period
grouped_data = data.groupby('YearMonth')['Revenue'].sum().reset_index()

# Plotting the revenue changes over time
plt.figure(figsize=(10, 6))
plt.plot(grouped_data['YearMonth'], grouped_data['Revenue'], marker='o', color='blue', label='Total Revenue')
plt.title("Changes in Revenue Over Time", fontsize=14)
plt.xlabel("Year-Month", fontsize=12)
plt.ylabel("Revenue", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
